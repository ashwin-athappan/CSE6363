# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install matplotlib
# !pip3 install scikit-learn
# !pip3 install pickle

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
# Import LinearRegression class from LinearRegression.py

import importlib
import LinearRegression

importlib.reload(LinearRegression)

LR = LinearRegression.LinearRegression

# %% [markdown]
# # 1.5 Regression with a single output

# %% [markdown]
# ### 1.5.2 Training

# %% [markdown]
# #### train_regression1.py

# %%
# Given petal length and petal width, predict sepal length.

petal_iris_data = load_iris()

petal_df = pd.DataFrame(petal_iris_data.data, columns=petal_iris_data.feature_names)

X_lr_pl_pw_sl = petal_df[['petal length (cm)', 'petal width (cm)']].values
y_lr_pl_pw_sl = petal_df['sepal length (cm)'].values

split_index = int(0.9 * len(X_lr_pl_pw_sl))
X_lr_pl_pw_sl_train, X_lr_pl_pw_sl_test = X_lr_pl_pw_sl[:split_index], X_lr_pl_pw_sl[split_index:]
y_lr_pl_pw_sl_train, y_lr_pl_pw_sl_test = y_lr_pl_pw_sl[:split_index], y_lr_pl_pw_sl[split_index:]

lr_pl_pw_sl = LR()

# Load the model if it has been trained before
lr_pl_pw_sl.load('lr_pl_pw_sl.pkl')
if not lr_pl_pw_sl.loaded:
    lr_pl_pw_sl.fit(X_lr_pl_pw_sl_train, y_lr_pl_pw_sl_train)
    lr_pl_pw_sl.save('lr_pl_pw_sl.pkl')
pl_pw_sl_history = lr_pl_pw_sl.loss_history
# Out:
# File lr_pl_pw_sl.pkl not found
# Training completed with final validation loss 0.958330

# %% [markdown]
# #### train_regression2.py

# %%
# Given petal length and petal width, predict sepal width.
petal_iris_data = load_iris()

petal_df = pd.DataFrame(petal_iris_data.data, columns=petal_iris_data.feature_names)

X_lr_pl_pw_sw = petal_df[['petal length (cm)', 'petal width (cm)']].values
y_lr_pl_pw_sw = petal_df['sepal width (cm)'].values

split_index = int(0.9 * len(X_lr_pl_pw_sw))
X_lr_pl_pw_sw_train, X_lr_pl_pw_sw_test = X_lr_pl_pw_sw[:split_index], X_lr_pl_pw_sw[split_index:]
y_lr_pl_pw_sw_train, y_lr_pl_pw_sw_test = y_lr_pl_pw_sw[:split_index], y_lr_pl_pw_sw[split_index:]

lr_pl_pw_sw = LR()

# Load the model if it has been trained before
lr_pl_pw_sw.load('lr_pl_pw_sw.pkl')
if not lr_pl_pw_sw.loaded:
    lr_pl_pw_sw.fit(X_lr_pl_pw_sw_train, y_lr_pl_pw_sw_train)
    lr_pl_pw_sw.save('lr_pl_pw_sw.pkl')
pl_pw_sw_history = lr_pl_pw_sw.loss_history
# Out:
# File lr_pl_pw_sw.pkl not found
# Training completed with final validation loss 0.100794

# %% [markdown]
# #### train_regression3.py

# %%
# Given sepal length and sepal width, predict petal length.
petal_iris_data = load_iris()

petal_df = pd.DataFrame(petal_iris_data.data, columns=petal_iris_data.feature_names)

X_lr_sl_sw_pl = petal_df[['sepal length (cm)', 'sepal width (cm)']].values
y_lr_sl_sw_pl = petal_df['petal length (cm)'].values

split_index = int(0.9 * len(X_lr_sl_sw_pl))
X_lr_sl_sw_pl_train, X_lr_sl_sw_pl_test = X_lr_sl_sw_pl[:split_index], X_lr_sl_sw_pl[split_index:]
y_lr_sl_sw_pl_train, y_lr_sl_sw_pl_test = y_lr_sl_sw_pl[:split_index], y_lr_sl_sw_pl[split_index:]

lr_sl_sw_pl = LR()
lr_sl_sw_pl.load('lr_sl_sw_pl.pkl')

# Load the model if it has been trained before
if not lr_sl_sw_pl.loaded:
    lr_sl_sw_pl.fit(X_lr_sl_sw_pl_train, y_lr_sl_sw_pl_train)
    lr_sl_sw_pl.save('lr_sl_sw_pl.pkl')
sl_sw_pl_history = lr_sl_sw_pl.loss_history
# Out:
# File lr_sl_sw_pl.pkl not found
# Training completed with final validation loss 3.336473

# %% [markdown]
# #### train_regression4.py

# %%
# Given sepal length and sepal width, predict petal width.
petal_iris_data = load_iris()

petal_df = pd.DataFrame(petal_iris_data.data, columns=petal_iris_data.feature_names)

X_lr_sl_sw_pw = petal_df[['sepal length (cm)', 'sepal width (cm)']].values
y_lr_sl_sw_pw = petal_df['petal width (cm)'].values

split_index = int(0.9 * len(X_lr_sl_sw_pw))
X_lr_sl_sw_pw_train, X_lr_sl_sw_pw_test = X_lr_sl_sw_pw[:split_index], X_lr_sl_sw_pw[split_index:]
y_lr_sl_sw_pw_train, y_lr_sl_sw_pw_test = y_lr_sl_sw_pw[:split_index], y_lr_sl_sw_pw[split_index:]

lr_sl_sw_pw = LR()

# Load the model if it has been trained before
lr_sl_sw_pw.load('lr_sl_sw_pw.pkl')
if not lr_sl_sw_pw.loaded:
    lr_sl_sw_pw.fit(X_lr_sl_sw_pw_train, y_lr_sl_sw_pw_train)
    lr_sl_sw_pw.save('lr_sl_sw_pw.pkl')
sl_sw_pw_history = lr_sl_sw_pw.loss_history
# Out:
# File lr_sl_sw_pw.pkl not found
# Training completed with final validation loss 0.546968

# %% [markdown]
# #### Comparison of 4 models

# %%
# Plot the loss history for each model

figure, axis = plt.subplots(2, 2, figsize=(20, 10))

x_axis = np.arange(0, len(pl_pw_sl_history))
axis[0, 0].plot(x_axis, pl_pw_sl_history, label='Petal length and width to find sepal length', color='red')
axis[0, 0].set_title('Petal length and width to find sepal length')

x_axis = np.arange(0, len(pl_pw_sw_history))
axis[0, 1].plot(x_axis, pl_pw_sw_history, label='Petal length and width to find sepal width', color='blue')
axis[0, 1].set_title('Petal length and width to find sepal width')

x_axis = np.arange(0, len(sl_sw_pl_history))
axis[1, 0].plot(x_axis, sl_sw_pl_history, label='Sepal length and width to find petal length', color='green')
axis[1, 0].set_title('Sepal length and width to find petal length')

x_axis = np.arange(0, len(sl_sw_pw_history))
axis[1, 1].plot(x_axis, sl_sw_pw_history, label='Sepal length and width to find petal width', color='orange')
axis[1, 1].set_title('Sepal length and width to find petal width')

plt.show()

# %% [markdown]
# ### 1.5.3 Regularization

# %% [markdown]
# #### regularization_train.py

# %%
# Given petal length and petal width, predict sepal length with regularization.

petal_iris_data = load_iris()

petal_df = pd.DataFrame(petal_iris_data.data, columns=petal_iris_data.feature_names)

X_regularization = petal_df[['sepal length (cm)', 'sepal width (cm)']].values
y_regularization = petal_df['petal length (cm)'].values

split_index = int(0.9 * len(X_regularization))
X_regularization_train, X_regularization_test = X_regularization[:split_index], X_regularization[split_index:]
y_regularization_train, y_regularization_test = y_regularization[:split_index], y_regularization[split_index:]

lr_regularization = LR()

# Load the model if it has been trained before
lr_regularization.load('lr_regularization.pkl')
if not lr_regularization.loaded:
    lr_regularization.fit(X_regularization_train, y_regularization_train, regularization=2.0)
    lr_regularization.save('lr_regularization.pkl')
regularization_history = lr_regularization.loss_history

# Plot the loss history
plt.plot(regularization_history, label='Regularization')
# Out:
# File lr_regularization.pkl not found
# Training completed with final validation loss 3.336819

# %% [markdown]
# #### Comparing with and without regularization

# %%
# Load the model without regularization
lr_sl_sw_pw.load('lr_sl_sw_pw.pkl')

# Load the model with regularization
lr_regularization.load('lr_regularization.pkl')

# Plot the loss history for both models
plt.plot(sl_sw_pw_history, label='Without Regularization', color='red')
plt.plot(regularization_history, label='With Regularization', color='green')

print('Weight of the model without regularization:', lr_sl_sw_pw.weights)
print('Bias of the model without regularization:', lr_sl_sw_pw.bias)
print('Weight of the model with regularization:', lr_regularization.weights)
print('Bias of the model with regularization:', lr_regularization.bias)
# Out:
# Model loaded from lr_sl_sw_pw.pkl
# Model loaded from lr_regularization.pkl
# Weight of the model without regularization: [0.14721342 0.05114628]
# Bias of the model without regularization: 0.020537224278250048
# Weight of the model with regularization: [0.47422087 0.18443113]
# Bias of the model with regularization: 0.07059505743080348

# %% [markdown]
# ### 1.5.4 Testing

# %% [markdown]
# #### eval_regression1.py

# %%
lr_pl_pw_sl.score(X_lr_pl_pw_sl_test, y_lr_pl_pw_sl_test)
# Out:
# 42.726666666666674

# %% [markdown]
# #### eval_regression2.py

# %%
lr_pl_pw_sw.score(X_lr_pl_pw_sw_test, y_lr_pl_pw_sw_test)
# Out:
# 9.415333333333333

# %% [markdown]
# #### eval_regression3.py

# %%
lr_sl_sw_pl.score(X_lr_sl_sw_pl_test, y_lr_sl_sw_pl_test)
# Out:
# 29.063333333333336

# %% [markdown]
# #### eval_regression4.py

# %%
lr_sl_sw_pw.score(X_lr_sl_sw_pw_test, y_lr_sl_sw_pw_test)
# Out:
# 4.638

# %% [markdown]
# Out of the four experiments that I have conducted the <b>sepal length, sepal width</b> inputs and <b>petal_width</b> output gave the least loss so these input features are the most predictive of the output features. Therefore, <u>lr_sl_sw_pw</u> is the best model.

# %% [markdown]
# # 1.6 Regression with Multiple Outputs

# %%
# Given petal length and petal width, predict sepal length and sepal width.

petal_iris_data = load_iris()

petal_df = pd.DataFrame(petal_iris_data.data, columns=petal_iris_data.feature_names)

X_lr_pl_pw_sl_sw = petal_df[['petal length (cm)', 'petal width (cm)']].values
y_lr_pl_pw_sl_sw = petal_df[['sepal length (cm)', 'sepal width (cm)']].values

split_index = int(0.9 * len(X_lr_pl_pw_sl))
X_lr_pl_pw_sl_sw_train, X_lr_pl_pw_sl_sw_test = X_lr_pl_pw_sl_sw[:split_index], X_lr_pl_pw_sl_sw[split_index:]
y_lr_pl_pw_sl_sw_train, y_lr_pl_pw_sl_sw_test = y_lr_pl_pw_sl_sw[:split_index], y_lr_pl_pw_sl_sw[split_index:]

lr_pl_pw_sl_sw = LR()

# Load the model if it has been trained before
lr_pl_pw_sl_sw.load('lr_pl_pw_sl_sw.pkl')
if not lr_pl_pw_sl_sw.loaded:
    lr_pl_pw_sl_sw.fit(X_lr_pl_pw_sl_sw_train, y_lr_pl_pw_sl_sw_train)
    lr_pl_pw_sl_sw.save('lr_pl_pw_sl_sw.pkl')
pl_pw_sl_sw_history = lr_pl_pw_sl_sw.loss_history

# Plot the loss history
plt.plot(pl_pw_sl_sw_history, label='Petal length and width to find sepal length and width')
# Out:
# File lr_pl_pw_sl_sw.pkl not found
# Training completed with final validation loss 0.474588
